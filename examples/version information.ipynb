# %% [markdown]
# Requires `version_information` and `tabulate`.

# %%
# %load_ext version_information

# %%
info = %version_information numpy, scipy, numba, sympy, tqdm

# %%
from tabulate import tabulate

print(tabulate(info.packages, tablefmt="rst"))
# Out:
# =======  ===================================
# Python   3.14.6 64bit [Clang 20.1.8 ]
# IPython  9.14.1
# OS       macOS 26.4.1 arm64 arm 64bit Mach O
# numpy    2.4.6
# scipy    1.18.0
# numba    0.65.1
# sympy    1.14.0
# tqdm     4.68.3
# =======  ===================================
